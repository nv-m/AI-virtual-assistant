# %%
# import stuff for chatbot
# this doesnt work in colab : use jupyter-notebook  becuase the module win32com 
# is not available in colab
# you will need to install these for the first time usage 
# !pip install gtts
# !pip install pyhibp
import pyhibp
from pyhibp import pwnedpasswords as pw
from gtts import gTTS #Import Google Text to Speech
from IPython.display import Audio #Import Audio method from IPython's Display Class
from keras.models import Sequential
from keras.losses import categorical_crossentropy
from keras.optimizers import SGD
from keras.layers import Dense
from numpy import argmax
import numpy as np
import re
#re-made
import requests
import bs4
from bs4 import BeautifulSoup
import nltk # to process text data
import numpy as np # to represent corpus as arrays
import random 
import string # to process standard python strings
'''from sklearn.metrics.pairwise import cosine_similarity # We will use this later to decide how similar two sentences are
from sklearn.feature_extraction.text import TfidfVectorizer
# Remember when you built a function to create a tfidf bag of words in Experience 2? This function does the same thing!
nltk.download('punkt') # first-time use only tokenizer
nltk.download('wordnet') # first-time use only Used for the lemmatizer
'''


# start training
a_do=['what can you do?','what all can you do?','show me what you can do']
a_greets = ["hi", "hello",
            "hey", "helloo", "hellooo",
            "g morining", "gmorning",
            "good morning", "morning", "good day",
            "good afternoon", "good evening", "greetings",
            "greeting", "good to see you", "its good seeing you",
            "g’day"]
a_hows = ["how are you", "how're you", "how are you doing","how ya doin", "how is everything", "how is everything going","how are things","how're things", "how is it going", "how's it going","how's it goin'", "how's it goin", "how is life been treating you,", "hows life been treating you", "how have you been", "how've you been"]
a_whats = ["what are you doing?","what is up", "what's up", "what is cracking","what's cracking", "what is happening", "what's happening", "what is new", "what's new", "what is new"]
a_population=['what is the population of india',
              'what is the population of place',
              'what is the population',
              'name the population',
              'tottal population of country',
              'how many people in india',
              'tottal population of'
              'population of'
              'population']
a_gl = ["search google","google","check on google","go to google",
        'search for the fastest animal','search in google','got to search',
        'start search',
        'do a google search',
        'perform  a google search',
        'performa a search']
a_summary = ['summarize','summarise','can you summarize this',
               'summarise','summary',
               'summarise','write the summary',
               'give the summary',
               'summaries',
               'shorten this text',
               'shorten',
               'short',
               'summary',
               'summaries']
a_bye = ['tata','catch you later','see you later','bye','bye bye','am going','bye',
         'bye-bye','adios','cheerio','ciao','bii','bii bii']
a_weather =['what is the weather ?','how is the weather','hows weather',
            'show weather','weather']
a_game = ['can we play a game','lets play a game','would you like to play a game?','come on lets play a game',
          'play a game','start a game','time to play','play a game','lets play','play something','can we play?']
      
b_greets = ["hi", "hello",
            "hey", "helloo", "hellooo",
            "g morining", "gmorning",
            "good morning", "morning", "good day",
            "good afternoon", "good evening", "greetings",
            "greeting", "good to see you", "its good seeing you",
            "g’day", "howdy"]
a_pawned = ["have i been pawned","check pawned","pawned","have i been breached","breach","is there a data breach","check for breach",
           "am i breached","is my password safe","is my credentials secure?",
           "check credentials"]
b_hows = ["cool",'am good','awesome!','i was born cool!']

b_whats = ["listening to you","waiting for a task","nothing much"]
b_bye=['tata','catch you later','see you later','bye','bye bye',
       'adios','cheerio','ciao']
X=[]
X = a_hows + a_whats + a_greets + a_do + a_gl + a_weather + a_game + a_bye + a_population + a_pawned + a_summary
responses = b_greets + b_hows + b_whats + a_bye
Y=[]
g=['google']
C=[]
for i in X:
  if i in a_whats:
    C.append('whats')
  elif i in a_hows:
    C.append('hows')
  elif i in a_greets:
    C.append('greets')
  elif i in a_do:
    C.append('do')
  elif i in a_gl:
    C.append('google')
  elif i in a_weather:
    C.append('weather')
  elif i in a_game:
    C.append('game')
  elif i in a_bye:
    C.append('bye')
  elif i in a_population:
    C.append('population')
  elif i in a_pawned:
    C.append('pawned')
  elif i in a_summary:
    C.append('summary')
Y=C
print(X,Y,sep='\n')
print(len(X),len(Y))
print('Hii, am dex! ','what can i do for you?','you can try typing : what can you do?',sep='\n')

Y=C
# Out:
# Requirement already satisfied: gtts in /usr/local/lib/python3.7/dist-packages (2.2.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from gtts) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gtts) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gtts) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gtts) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gtts) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gtts) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gtts) (1.24.3)
# Requirement already satisfied: pyhibp in /usr/local/lib/python3.7/dist-packages (4.2.0)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from pyhibp) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->pyhibp) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->pyhibp) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->pyhibp) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->pyhibp) (1.24.3)
# ['how are you', "how're you", 'how are you doing', 'how ya doin', 'how is everything', 'how is everything going', 'how are things', "how're things", 'how is it going', "how's it going", "how's it goin'", "how's it goin", 'how is life been treating you,', 'hows life been treating you', 'how have you been', "how've you been", 'what are you doing?', 'what is up', "what's up", 'what is cracking', "what's cracking", 'what is happening', "what's happening", 'what is new', "what's new", 'what is new', 'hi', 'hello', 'hey', 'helloo', 'hellooo', 'g morining', 'gmorning', 'good morning', 'morning', 'good day', 'good afternoon', 'good evening', 'greetings', 'greeting', 'good to see you', 'its good seeing you', 'g’day', 'what can you do?', 'what all can you do?', 'show me what you can do', 'search google', 'google', 'check on google', 'go to google', 'search for the fastest animal', 'search in google', 'got to search', 'start search', 'do a google search', 'perform  a google search', 'performa a search', 'what is the weather ?', 'how is the weather', 'hows weather', 'show weather', 'weather', 'can we play a game', 'lets play a game', 'would you like to play a game?', 'come on lets play a game', 'play a game', 'start a game', 'time to play', 'play a game', 'lets play', 'play something', 'can we play?', 'tata', 'catch you later', 'see you later', 'bye', 'bye bye', 'am going', 'bye', 'bye-bye', 'adios', 'cheerio', 'ciao', 'bii', 'bii bii', 'what is the population of india', 'what is the population of place', 'what is the population', 'name the population', 'tottal population of country', 'how many people in india', 'tottal population ofpopulation ofpopulation', 'have i been pawned', 'check pawned', 'pawned', 'have i been breached', 'breach', 'is there a data breach', 'check for breach', 'am i breached', 'is my password safe', 'is my credentials secure?', 'check credentials', 'summarize', 'summarise', 'can you summarize this', 'summarise', 'summary', 'summarise', 'write the summary', 'give the summary', 'summaries', 'shorten this text', 'shorten', 'short', 'summary', 'summaries']
# ['hows', 'hows', 'hows', 'hows', 'hows', 'hows', 'hows', 'hows', 'hows', 'hows', 'hows', 'hows', 'hows', 'hows', 'hows', 'hows', 'whats', 'whats', 'whats', 'whats', 'whats', 'whats', 'whats', 'whats', 'whats', 'whats', 'greets', 'greets', 'greets', 'greets', 'greets', 'greets', 'greets', 'greets', 'greets', 'greets', 'greets', 'greets', 'greets', 'greets', 'greets', 'greets', 'greets', 'do', 'do', 'do', 'google', 'google', 'google', 'google', 'google', 'google', 'google', 'google', 'google', 'google', 'google', 'weather', 'weather', 'weather', 'weather', 'weather', 'game', 'game', 'game', 'game', 'game', 'game', 'game', 'game', 'game', 'game', 'game', 'bye', 'bye', 'bye', 'bye', 'bye', 'bye', 'bye', 'bye', 'bye', 'bye', 'bye', 'bye', 'bye', 'population', 'population', 'population', 'population', 'population', 'population', 'population', 'pawned', 'pawned', 'pawned', 'pawned', 'pawned', 'pawned', 'pawned', 'pawned', 'pawned', 'pawned', 'pawned', 'summary', 'summary', 'summary', 'summary', 'summary', 'summary', 'summary', 'summary', 'summary', 'summary', 'summary', 'summary', 'summary', 'summary']
# 118 118
# Hii, am dex!
# what can i do for you?
# you can try typing : what can you do?

# %%
# population by place

# population
def population():
  global popu
  global city
# Taking thecity name as an input from the user
  city = input("Type the name of the country/state/district :  ")
  
# Generating the url  
  url = "https://google.com/search?q=population+in+" + city
  
# Sending HTTP request 
  request_result = requests.get( url )
  
# Pulling HTTP data from internet 
  soup = bs4.BeautifulSoup( request_result.text 
                         , "html.parser" )
  
# Finding temperature in Celsius.
# The temperature is stored inside the class "BNeawe". 
  popu = soup.find( "div" , class_='BNeawe' ).text

# %%
# weather - using bs4
def weather():
  global temp
  
# Taking thecity name as an input from the user
  city = input('where are you now?  :   ')
  
# Generating the url  
  url = "https://google.com/search?q=weather+in+" + city
  
# Sending HTTP request 
  request_result = requests.get( url )
  
# Pulling HTTP data from internet 
  soup = bs4.BeautifulSoup( request_result.text ,
                           "html.parser" )
  
# Finding temperature in Celsius.
# The temperature is stored inside the class "BNeawe". 
  temp = soup.find( "div" , class_='BNeawe' ).text 
  k=''   
  kc='°C'
  for i in temp:
    if i.isdigit():
      k=k+i
  k=int(k)
  c=(k-32)*(5/9)
  c=int(c)
  c=str(c)
  temp=c+kc

# %%
def search():
  global stat
  global heading_object
  print('what do you want to search for?  ')
  text=input()
  url = 'https://google.com/search?q=' + text
  
# Fetch the URL data using requests.get(url),
# store it in a variable, request_result.
  request_result=requests.get( url )
  
# Creating soup from the fetched request
  soup = bs4.BeautifulSoup(request_result.text,
                           "html.parser")
  heading_object=soup.find_all( 'h3' )
  
# Iterate through the object 
# and print it as a string.
  for info in heading_object:
      print(info.getText())
      print("------")
  stat=heading_object

# %%
#processing


def remove_non_alpha_numeric_characters(sentence):
    new_sentence = ''
    for alphabet in sentence:
        if alphabet.isalpha() or alphabet == ' ':
            new_sentence += alphabet
    return new_sentence
    sentence=remove_non_alphanumeric_characters(sentence)
    
        
  #

def preprocess_data(X):
  X = [data_point.lower() for data_point in X]
  X = [remove_non_alpha_numeric_characters(
       sentence) for sentence in X]
  X = [data_point.strip() for data_point in X]
  X = [re.sub(' +', ' ',
              data_point) for data_point in X]
  return X
  

  #
  #pre_process
X = preprocess_data(X)
vocabulary = set()
for data_point in X:
    for word in data_point.split(' '):
         vocabulary.add(word)

vocabulary = list(vocabulary)



  #

X_encoded = []

def encode_sentence(sentence):
    sentence = preprocess_data([sentence])[0]
    sentence_encoded = [0] * len(vocabulary)
    for i in range(len(vocabulary)):
       if vocabulary[i] in sentence.split(' '):
          sentence_encoded[i] = 1
    return sentence_encoded

X_encoded = [encode_sentence(sentence) for sentence in X]


classes = list(set(Y))

Y_encoded = []
for data_point in Y:
  data_point_encoded = [0] * len(classes)
  for i in range(len(classes)):
     if classes[i] == data_point:
       data_point_encoded[i] = 1
       Y_encoded.append(data_point_encoded)


  # train data

X_train = X_encoded
y_train = Y_encoded
X_test = X_encoded
y_test = Y_encoded




  #print and check


y_train

  # model training

model = Sequential()
model.add(Dense(units=64, activation='sigmoid',
                input_dim=len(X_train[0])))
model.add(Dense(units=len(y_train[0]), activation='softmax'))
model.compile(loss=categorical_crossentropy,
              optimizer=SGD(lr=0.01,
                            momentum=0.9, nesterov=True))
model.fit(np.array(X_train), np.array(y_train), epochs=1500, batch_size=16)
  
  
  #list prediction

predictions = [argmax(pred) for pred in model.predict(np.array(X_test))]


  # model evaluation

correct = 0
for i in range(len(predictions)):
    if predictions[i] == argmax(y_test[i]):
        correct += 1

print ("Correct:", correct)
print ("Total:", len(predictions))
# Out:
# Epoch 1/1500
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# 8/8 [==============================] - 0s 2ms/step - loss: 2.7038
# Epoch 2/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.4760
# Epoch 3/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.3240
# Epoch 4/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.3220
# Epoch 5/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2970
# Epoch 6/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2924
# Epoch 7/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2911
# Epoch 8/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2674
# Epoch 9/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2706
# Epoch 10/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2676
# Epoch 11/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 2.2743
# Epoch 12/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2490
# Epoch 13/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2958
# Epoch 14/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2508
# Epoch 15/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2858
# Epoch 16/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2702
# Epoch 17/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2586
# Epoch 18/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2448
# Epoch 19/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 2.2373
# Epoch 20/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 2.2125
# Epoch 21/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2241
# Epoch 22/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2083
# Epoch 23/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2157
# Epoch 24/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.1456
# Epoch 25/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.1762
# Epoch 26/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.1822
# Epoch 27/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.1688
# Epoch 28/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.1218
# Epoch 29/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.1206
# Epoch 30/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.1288
# Epoch 31/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.1071
# Epoch 32/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.1165
# Epoch 33/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0878
# Epoch 34/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0583
# Epoch 35/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0922
# Epoch 36/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0992
# Epoch 37/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0250
# Epoch 38/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0574
# Epoch 39/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0474
# Epoch 40/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0051
# Epoch 41/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9473
# Epoch 42/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0253
# Epoch 43/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9866
# Epoch 44/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9631
# Epoch 45/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9515
# Epoch 46/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 1.9516
# Epoch 47/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 1.9558
# Epoch 48/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9321
# Epoch 49/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9046
# Epoch 50/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8939
# Epoch 51/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8512
# Epoch 52/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8200
# Epoch 53/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8513
# Epoch 54/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8565
# Epoch 55/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8297
# Epoch 56/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 1.8340
# Epoch 57/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7713
# Epoch 58/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7913
# Epoch 59/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7615
# Epoch 60/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 1.7267
# Epoch 61/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7797
# Epoch 62/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6586
# Epoch 63/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7359
# Epoch 64/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 1.6424
# Epoch 65/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6697
# Epoch 66/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6344
# Epoch 67/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5938
# Epoch 68/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7272
# Epoch 69/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6047
# Epoch 70/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6159
# Epoch 71/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6443
# Epoch 72/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 1.5637
# Epoch 73/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5802
# Epoch 74/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 1.5180
# Epoch 75/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 1.5188
# Epoch 76/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5063
# Epoch 77/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4979
# Epoch 78/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4689
# Epoch 79/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4957
# Epoch 80/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4273
# Epoch 81/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4582
# Epoch 82/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4112
# Epoch 83/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4411
# Epoch 84/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4403
# Epoch 85/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3754
# Epoch 86/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3533
# Epoch 87/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3391
# Epoch 88/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3456
# Epoch 89/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3643
# Epoch 90/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 1.2508
# Epoch 91/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2913
# Epoch 92/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 1.2961
# Epoch 93/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3094
# Epoch 94/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2659
# Epoch 95/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1788
# Epoch 96/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1877
# Epoch 97/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2144
# Epoch 98/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1520
# Epoch 99/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1921
# Epoch 100/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 1.1995
# Epoch 101/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2501
# Epoch 102/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1223
# Epoch 103/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1129
# Epoch 104/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0335
# Epoch 105/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1160
# Epoch 106/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0856
# Epoch 107/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1366
# Epoch 108/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0415
# Epoch 109/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0428
# Epoch 110/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0474
# Epoch 111/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0533
# Epoch 112/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9776
# Epoch 113/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9954
# Epoch 114/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.9729
# Epoch 115/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9498
# Epoch 116/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9560
# Epoch 117/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9336
# Epoch 118/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9091
# Epoch 119/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9447
# Epoch 120/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9370
# Epoch 121/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9736
# Epoch 122/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9563
# Epoch 123/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8521
# Epoch 124/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8991
# Epoch 125/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9125
# Epoch 126/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8565
# Epoch 127/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8293
# Epoch 128/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8406
# Epoch 129/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8224
# Epoch 130/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8077
# Epoch 131/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7391
# Epoch 132/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7926
# Epoch 133/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7830
# Epoch 134/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7930
# Epoch 135/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7931
# Epoch 136/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7866
# Epoch 137/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7424
# Epoch 138/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7008
# Epoch 139/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7197
# Epoch 140/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7470
# Epoch 141/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6990
# Epoch 142/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7160
# Epoch 143/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6868
# Epoch 144/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7125
# Epoch 145/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6781
# Epoch 146/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6671
# Epoch 147/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5992
# Epoch 148/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6476
# Epoch 149/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5762
# Epoch 150/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6396
# Epoch 151/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6469
# Epoch 152/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6318
# Epoch 153/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6389
# Epoch 154/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5845
# Epoch 155/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6239
# Epoch 156/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6024
# Epoch 157/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6082
# Epoch 158/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5657
# Epoch 159/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5747
# Epoch 160/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5514
# Epoch 161/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5249
# Epoch 162/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5395
# Epoch 163/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5802
# Epoch 164/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5337
# Epoch 165/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5497
# Epoch 166/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5503
# Epoch 167/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5315
# Epoch 168/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5455
# Epoch 169/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5151
# Epoch 170/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5086
# Epoch 171/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4421
# Epoch 172/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5235
# Epoch 173/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4472
# Epoch 174/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5252
# Epoch 175/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4374
# Epoch 176/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4756
# Epoch 177/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4415
# Epoch 178/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4736
# Epoch 179/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4604
# Epoch 180/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4648
# Epoch 181/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4209
# Epoch 182/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4330
# Epoch 183/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4120
# Epoch 184/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4179
# Epoch 185/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4308
# Epoch 186/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3900
# Epoch 187/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3708
# Epoch 188/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4041
# Epoch 189/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3698
# Epoch 190/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3984
# Epoch 191/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4067
# Epoch 192/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4040
# Epoch 193/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4107
# Epoch 194/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4044
# Epoch 195/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3582
# Epoch 196/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3820
# Epoch 197/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3794
# Epoch 198/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3858
# Epoch 199/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3559
# Epoch 200/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3595
# Epoch 201/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3485
# Epoch 202/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3438
# Epoch 203/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3163
# Epoch 204/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3448
# Epoch 205/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3396
# Epoch 206/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3438
# Epoch 207/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3207
# Epoch 208/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3560
# Epoch 209/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3330
# Epoch 210/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3358
# Epoch 211/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3232
# Epoch 212/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3113
# Epoch 213/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2944
# Epoch 214/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3223
# Epoch 215/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3049
# Epoch 216/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2995
# Epoch 217/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3072
# Epoch 218/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2990
# Epoch 219/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2775
# Epoch 220/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2691
# Epoch 221/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2803
# Epoch 222/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2584
# Epoch 223/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2838
# Epoch 224/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2788
# Epoch 225/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2743
# Epoch 226/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2607
# Epoch 227/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2540
# Epoch 228/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2511
# Epoch 229/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2440
# Epoch 230/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2627
# Epoch 231/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2423
# Epoch 232/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2718
# Epoch 233/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2400
# Epoch 234/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2304
# Epoch 235/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2486
# Epoch 236/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2395
# Epoch 237/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2614
# Epoch 238/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2423
# Epoch 239/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2227
# Epoch 240/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2322
# Epoch 241/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2189
# Epoch 242/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2238
# Epoch 243/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2490
# Epoch 244/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2086
# Epoch 245/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2157
# Epoch 246/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2325
# Epoch 247/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2166
# Epoch 248/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2155
# Epoch 249/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2285
# Epoch 250/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2219
# Epoch 251/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2062
# Epoch 252/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2110
# Epoch 253/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2023
# Epoch 254/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1883
# Epoch 255/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1837
# Epoch 256/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1985
# Epoch 257/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2013
# Epoch 258/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2075
# Epoch 259/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1973
# Epoch 260/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1805
# Epoch 261/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1970
# Epoch 262/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1908
# Epoch 263/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1679
# Epoch 264/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1952
# Epoch 265/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1626
# Epoch 266/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1989
# Epoch 267/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1803
# Epoch 268/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1798
# Epoch 269/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1760
# Epoch 270/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1707
# Epoch 271/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1881
# Epoch 272/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1881
# Epoch 273/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1662
# Epoch 274/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1821
# Epoch 275/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1786
# Epoch 276/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1771
# Epoch 277/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1722
# Epoch 278/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1543
# Epoch 279/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1662
# Epoch 280/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1604
# Epoch 281/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1603
# Epoch 282/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1462
# Epoch 283/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1581
# Epoch 284/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1501
# Epoch 285/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1518
# Epoch 286/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1514
# Epoch 287/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1552
# Epoch 288/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1317
# Epoch 289/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1531
# Epoch 290/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1666
# Epoch 291/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1488
# Epoch 292/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1466
# Epoch 293/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1525
# Epoch 294/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1476
# Epoch 295/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1402
# Epoch 296/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1554
# Epoch 297/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1221
# Epoch 298/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1437
# Epoch 299/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1340
# Epoch 300/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1352
# Epoch 301/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1414
# Epoch 302/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1321
# Epoch 303/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1371
# Epoch 304/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1298
# Epoch 305/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1278
# Epoch 306/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1305
# Epoch 307/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1294
# Epoch 308/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1243
# Epoch 309/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1206
# Epoch 310/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1232
# Epoch 311/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1187
# Epoch 312/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1270
# Epoch 313/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1214
# Epoch 314/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1227
# Epoch 315/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1305
# Epoch 316/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1415
# Epoch 317/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1104
# Epoch 318/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1255
# Epoch 319/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1237
# Epoch 320/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1169
# Epoch 321/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1091
# Epoch 322/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1141
# Epoch 323/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1152
# Epoch 324/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1101
# Epoch 325/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1148
# Epoch 326/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1189
# Epoch 327/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1061
# Epoch 328/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1125
# Epoch 329/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1027
# Epoch 330/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1076
# Epoch 331/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1044
# Epoch 332/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1081
# Epoch 333/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1029
# Epoch 334/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1090
# Epoch 335/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1058
# Epoch 336/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1049
# Epoch 337/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0999
# Epoch 338/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1011
# Epoch 339/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1057
# Epoch 340/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1046
# Epoch 341/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1106
# Epoch 342/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1034
# Epoch 343/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1042
# Epoch 344/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1013
# Epoch 345/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1092
# Epoch 346/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1054
# Epoch 347/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0955
# Epoch 348/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0911
# Epoch 349/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0977
# Epoch 350/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0877
# Epoch 351/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0922
# Epoch 352/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0917
# Epoch 353/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0891
# Epoch 354/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0880
# Epoch 355/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0910
# Epoch 356/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0912
# Epoch 357/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0945
# Epoch 358/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0846
# Epoch 359/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0954
# Epoch 360/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0854
# Epoch 361/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0948
# Epoch 362/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0845
# Epoch 363/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0857
# Epoch 364/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0971
# Epoch 365/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0888
# Epoch 366/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0747
# Epoch 367/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0830
# Epoch 368/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0938
# Epoch 369/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0823
# Epoch 370/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0967
# Epoch 371/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0808
# Epoch 372/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0846
# Epoch 373/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0834
# Epoch 374/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0699
# Epoch 375/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0814
# Epoch 376/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0767
# Epoch 377/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0840
# Epoch 378/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0775
# Epoch 379/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0865
# Epoch 380/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0765
# Epoch 381/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0907
# Epoch 382/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0804
# Epoch 383/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0846
# Epoch 384/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0817
# Epoch 385/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0760
# Epoch 386/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0771
# Epoch 387/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0703
# Epoch 388/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0838
# Epoch 389/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0752
# Epoch 390/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0743
# Epoch 391/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0866
# Epoch 392/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0773
# Epoch 393/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0673
# Epoch 394/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0707
# Epoch 395/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0716
# Epoch 396/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0784
# Epoch 397/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0644
# Epoch 398/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0741
# Epoch 399/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0732
# Epoch 400/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0721
# Epoch 401/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0705
# Epoch 402/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0612
# Epoch 403/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0738
# Epoch 404/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0677
# Epoch 405/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0681
# Epoch 406/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0616
# Epoch 407/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0702
# Epoch 408/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0644
# Epoch 409/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0707
# Epoch 410/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0668
# Epoch 411/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0717
# Epoch 412/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0690
# Epoch 413/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0624
# Epoch 414/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0644
# Epoch 415/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0616
# Epoch 416/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0660
# Epoch 417/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0664
# Epoch 418/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0648
# Epoch 419/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0655
# Epoch 420/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0621
# Epoch 421/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0632
# Epoch 422/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0602
# Epoch 423/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0639
# Epoch 424/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0599
# Epoch 425/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0592
# Epoch 426/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0578
# Epoch 427/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0634
# Epoch 428/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0705
# Epoch 429/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0591
# Epoch 430/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0594
# Epoch 431/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0558
# Epoch 432/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0548
# Epoch 433/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0573
# Epoch 434/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0535
# Epoch 435/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0603
# Epoch 436/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0545
# Epoch 437/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0576
# Epoch 438/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0529
# Epoch 439/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0509
# Epoch 440/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0578
# Epoch 441/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0570
# Epoch 442/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0560
# Epoch 443/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0590
# Epoch 444/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0599
# Epoch 445/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0589
# Epoch 446/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0538
# Epoch 447/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0499
# Epoch 448/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0475
# Epoch 449/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0570
# Epoch 450/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0522
# Epoch 451/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0570
# Epoch 452/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0526
# Epoch 453/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0521
# Epoch 454/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0529
# Epoch 455/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0534
# Epoch 456/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0570
# Epoch 457/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0553
# Epoch 458/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0542
# Epoch 459/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0487
# Epoch 460/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0488
# Epoch 461/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0538
# Epoch 462/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0510
# Epoch 463/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0541
# Epoch 464/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0474
# Epoch 465/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0469
# Epoch 466/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0455
# Epoch 467/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0464
# Epoch 468/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0542
# Epoch 469/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0476
# Epoch 470/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0482
# Epoch 471/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0494
# Epoch 472/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0510
# Epoch 473/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0414
# Epoch 474/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0510
# Epoch 475/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0440
# Epoch 476/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0533
# Epoch 477/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0409
# Epoch 478/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0521
# Epoch 479/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0507
# Epoch 480/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0483
# Epoch 481/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0529
# Epoch 482/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0469
# Epoch 483/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0460
# Epoch 484/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0471
# Epoch 485/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0441
# Epoch 486/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0424
# Epoch 487/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0429
# Epoch 488/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0442
# Epoch 489/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0448
# Epoch 490/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0382
# Epoch 491/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0450
# Epoch 492/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0476
# Epoch 493/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0421
# Epoch 494/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0461
# Epoch 495/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0360
# Epoch 496/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0437
# Epoch 497/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0454
# Epoch 498/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0422
# Epoch 499/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0469
# Epoch 500/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0489
# Epoch 501/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0424
# Epoch 502/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0417
# Epoch 503/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0412
# Epoch 504/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0381
# Epoch 505/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0407
# Epoch 506/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0438
# Epoch 507/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0438
# Epoch 508/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0427
# Epoch 509/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0421
# Epoch 510/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0387
# Epoch 511/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0401
# Epoch 512/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0372
# Epoch 513/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0419
# Epoch 514/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0414
# Epoch 515/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0451
# Epoch 516/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0430
# Epoch 517/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0441
# Epoch 518/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0398
# Epoch 519/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0382
# Epoch 520/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0444
# Epoch 521/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0412
# Epoch 522/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0424
# Epoch 523/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0424
# Epoch 524/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0417
# Epoch 525/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0373
# Epoch 526/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0376
# Epoch 527/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0370
# Epoch 528/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0369
# Epoch 529/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0380
# Epoch 530/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0325
# Epoch 531/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0384
# Epoch 532/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0395
# Epoch 533/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0373
# Epoch 534/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0404
# Epoch 535/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0380
# Epoch 536/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0386
# Epoch 537/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0343
# Epoch 538/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0407
# Epoch 539/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0361
# Epoch 540/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0378
# Epoch 541/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0368
# Epoch 542/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0384
# Epoch 543/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0388
# Epoch 544/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0369
# Epoch 545/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0372
# Epoch 546/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0361
# Epoch 547/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0351
# Epoch 548/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0375
# Epoch 549/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0376
# Epoch 550/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0367
# Epoch 551/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0350
# Epoch 552/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0383
# Epoch 553/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0338
# Epoch 554/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0333
# Epoch 555/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0319
# Epoch 556/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0337
# Epoch 557/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0314
# Epoch 558/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0386
# Epoch 559/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0333
# Epoch 560/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0361
# Epoch 561/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0355
# Epoch 562/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0306
# Epoch 563/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0300
# Epoch 564/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0358
# Epoch 565/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0321
# Epoch 566/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0288
# Epoch 567/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0350
# Epoch 568/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0318
# Epoch 569/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0349
# Epoch 570/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0325
# Epoch 571/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0352
# Epoch 572/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0340
# Epoch 573/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0305
# Epoch 574/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0308
# Epoch 575/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0365
# Epoch 576/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0309
# Epoch 577/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0319
# Epoch 578/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0328
# Epoch 579/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0319
# Epoch 580/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0314
# Epoch 581/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0359
# Epoch 582/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0301
# Epoch 583/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0312
# Epoch 584/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0336
# Epoch 585/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0300
# Epoch 586/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0275
# Epoch 587/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0307
# Epoch 588/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0290
# Epoch 589/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0325
# Epoch 590/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0328
# Epoch 591/1500
# ...
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0082
# Epoch 1307/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 1308/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0086
# Epoch 1309/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 1310/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0084
# Epoch 1311/1500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0076
# Epoch 1312/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0080
# Epoch 1313/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 1314/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 1315/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0087
# Epoch 1316/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 1317/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 1318/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 1319/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 1320/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0086
# Epoch 1321/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0088
# Epoch 1322/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0084
# Epoch 1323/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0089
# Epoch 1324/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 1325/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0079
# Epoch 1326/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 1327/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0083
# Epoch 1328/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0074
# Epoch 1329/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 1330/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0084
# Epoch 1331/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 1332/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0084
# Epoch 1333/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0080
# Epoch 1334/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0083
# Epoch 1335/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 1336/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 1337/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 1338/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0079
# Epoch 1339/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 1340/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 1341/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0081
# Epoch 1342/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0090
# Epoch 1343/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 1344/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 1345/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 1346/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 1347/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0081
# Epoch 1348/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0083
# Epoch 1349/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0078
# Epoch 1350/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 1351/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0086
# Epoch 1352/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0089
# Epoch 1353/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 1354/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 1355/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 1356/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0084
# Epoch 1357/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 1358/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0072
# Epoch 1359/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0074
# Epoch 1360/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 1361/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 1362/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 1363/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 1364/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 1365/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0079
# Epoch 1366/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 1367/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0082
# Epoch 1368/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 1369/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 1370/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 1371/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 1372/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 1373/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0077
# Epoch 1374/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 1375/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 1376/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 1377/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 1378/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 1379/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 1380/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 1381/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 1382/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 1383/1500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0078
# Epoch 1384/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 1385/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0078
# Epoch 1386/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0075
# Epoch 1387/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0085
# Epoch 1388/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0078
# Epoch 1389/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 1390/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 1391/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 1392/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 1393/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 1394/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 1395/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 1396/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0077
# Epoch 1397/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 1398/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 1399/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 1400/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 1401/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 1402/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0077
# Epoch 1403/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 1404/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 1405/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 1406/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 1407/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 1408/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 1409/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 1410/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 1411/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 1412/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 1413/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 1414/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0070
# Epoch 1415/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0074
# Epoch 1416/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 1417/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0074
# Epoch 1418/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 1419/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 1420/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 1421/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0080
# Epoch 1422/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 1423/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 1424/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 1425/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 1426/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 1427/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 1428/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 1429/1500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 1430/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0078
# Epoch 1431/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 1432/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 1433/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 1434/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 1435/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 1436/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 1437/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 1438/1500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0076
# Epoch 1439/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 1440/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 1441/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0063
# Epoch 1442/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 1443/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0075
# Epoch 1444/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0078
# Epoch 1445/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0064
# Epoch 1446/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 1447/1500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0070
# Epoch 1448/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0074
# Epoch 1449/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0070
# Epoch 1450/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 1451/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 1452/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0062
# Epoch 1453/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 1454/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 1455/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 1456/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 1457/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 1458/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0079
# Epoch 1459/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 1460/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 1461/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 1462/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 1463/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 1464/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 1465/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0069
# Epoch 1466/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 1467/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 1468/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 1469/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 1470/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0069
# Epoch 1471/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 1472/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0077
# Epoch 1473/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 1474/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 1475/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 1476/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 1477/1500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 1478/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 1479/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 1480/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 1481/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 1482/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 1483/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 1484/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0079
# Epoch 1485/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 1486/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 1487/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 1488/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 1489/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 1490/1500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 1491/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 1492/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 1493/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 1494/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 1495/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 1496/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 1497/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 1498/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 1499/1500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0077
# Epoch 1500/1500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0070
# Correct: 118
# Total: 118

# %%
def speech(a):
  tts=gTTS(a)
  tts.save('1.wav')
  sound_file='1.wav'
  return Audio(sound_file,autoplay=True)
sp='Hello , I am dex! what can i do for you'

# %%
def pawned():
# Required: A descriptive user agent must be set describing the application consuming
#   the HIBP API
  pyhibp.set_user_agent(ua="Awesome application/0.0.1 (An awesome description)")
  passw=input('enter a password to see if it has been breached : ')
  # Check a password to see if it has been disclosed in a public breach corpus
  resp = pw.is_password_breached(password=passw)

  if resp:
      print("Password breached!")
      print("This password was used {0} time(s) before.".format(resp))
  else:
    print("No breaches found")

  # Get data classes in the HIBP system
  resp = pyhibp.get_data_classes()

  # Get all breach information
  resp = pyhibp.get_all_breaches()

  # Get a single breach
  resp = pyhibp.get_single_breach(breach_name="Adobe")

  # An API key is required for calls which search by email address
  #   (so get_pastes/get_account_breaches)
  # See <https://haveibeenpwned.com/API/Key>
  HIBP_API_KEY = None

  if HIBP_API_KEY:
      # Set the API key prior to using the functions which require it.
      pyhibp.set_api_key(key=HIBP_API_KEY)

      # Get pastes affecting a given email address
      resp = pyhibp.get_pastes(email_address=email)

      # Get breaches that affect a given account
      resp = pyhibp.get_account_breaches(account=email, truncate_response=True)

# %%
# game
# tic tac toe
theBoard = {'7': ' ' , '8': ' ' , '9': ' ' ,
            '4': ' ' , '5': ' ' , '6': ' ' ,
            '1': ' ' , '2': ' ' , '3': ' ' }

board_keys = []

for key in theBoard:
    board_keys.append(key)

''' We will have to print the updated board after every move in the game and 
    thus we will make a function in which we'll define the printBoard function
    so that we can easily print the board everytime by calling this function. '''

def printBoard(board):
    print(board['7'] + '|' + board['8'] + '|' + board['9'])
    print('-+-+-')
    print(board['4'] + '|' + board['5'] + '|' + board['6'])
    print('-+-+-')
    print(board['1'] + '|' + board['2'] + '|' + board['3'])

# Now we'll write the main function which has all the gameplay functionality.
def game():

    turn = 'X'
    count = 0


    for i in range(10):
        printBoard(theBoard)
        print("It's your turn," + turn + ".Move to which place?")

        move = input()        

        if theBoard[move] == ' ':
            theBoard[move] = turn
            count += 1
        else:
            print("That place is already filled.\nMove to which place?")
            continue

        # Now we will check if player X or O has won,for every move after 5 moves. 
        if count >= 5:
            if theBoard['7'] == theBoard['8'] == theBoard['9'] != ' ': # across the top
                printBoard(theBoard)
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")                
                break
            elif theBoard['4'] == theBoard['5'] == theBoard['6'] != ' ': # across the middle
                printBoard(theBoard)
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break
            elif theBoard['1'] == theBoard['2'] == theBoard['3'] != ' ': # across the bottom
                printBoard(theBoard)
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break
            elif theBoard['1'] == theBoard['4'] == theBoard['7'] != ' ': # down the left side
                printBoard(theBoard)
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break
            elif theBoard['2'] == theBoard['5'] == theBoard['8'] != ' ': # down the middle
                printBoard(theBoard)
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break
            elif theBoard['3'] == theBoard['6'] == theBoard['9'] != ' ': # down the right side
                printBoard(theBoard)
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break 
            elif theBoard['7'] == theBoard['5'] == theBoard['3'] != ' ': # diagonal
                printBoard(theBoard)
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break
            elif theBoard['1'] == theBoard['5'] == theBoard['9'] != ' ': # diagonal
                printBoard(theBoard)
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break 

        # If neither X nor O wins and the board is full, we'll declare the result as 'tie'.
        if count == 9:
            print("\nGame Over.\n")                
            print("It's a Tie!!")

        # Now we have to change the player after every move.
        if turn =='X':
            turn = 'O'
        else:
            turn = 'X'        
    
    # Now we will ask if player wants to restart the game or not.
    restart = input("Do want to play Again?(y/n)")
    if restart == "y" or restart == "Y":  
        for key in board_keys:
            theBoard[key] = " "

        game()

# %%
#summary

# importing libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download('stopwords')
nltk.download('punkt')   
def fromlink():
  global text
  
  # get URL
  link=input('enter the link to the text  : ')
  page = requests.get(link)
  
  # scrape webpage
  soup = BeautifulSoup(page.content, 'html.parser')
  
  list(soup.children)
  
  # find all occurance of p in HTML
  # includes HTML tags
  soup.find_all('p')
  
  print('\n\n')
  
  # return only text
  # does not include HTML tags
  text = soup.find_all('p')[0].get_text()


def summary():
  global summary,text
  # Input text - to summarize 
  print('what do you want to summarize?')
  print('1) text ',' 2) a link to source text ',sep='\n')
  while True:

    inp=input()
    if inp=='1':
      text = input('enter the text to summarize it : ')
      break
    elif inp=='2':
      fromlink()
      break
  # Tokenizing the text
  stopWords = set(stopwords.words("english"))
  words = word_tokenize(text)
   
  # Creating a frequency table to keep the 
  # score of each word
   
  freqTable = dict()
  for word in words:
      word = word.lower()
      if word in stopWords:
          continue
      if word in freqTable:
          freqTable[word] += 1
      else:
          freqTable[word] = 1
   
  # Creating a dictionary to keep the score
  # of each sentence
  sentences = sent_tokenize(text)
  sentenceValue = dict()
   
  for sentence in sentences:
      for word, freq in freqTable.items():
          if word in sentence.lower():
              if sentence in sentenceValue:
                  sentenceValue[sentence] += freq
              else:
                  sentenceValue[sentence] = freq
   
   
   
  sumValues = 0
  for sentence in sentenceValue:
      sumValues += sentenceValue[sentence]
   
  # Average value of a sentence from the original text
   
  average = int(sumValues / len(sentenceValue))
   
  # Storing sentences into our summary.
  summary = ''
  for sentence in sentences:
      if (sentence in sentenceValue) and (sentenceValue[sentence] > (1.2 * average)):
          summary += " " + sentence
  print('length of input  : ',len(text))
  print('length of output : ',len(summary))
  input(' press enter to show the summary ')
  sumsplit=summary.split()
  for i in sumsplit:
    if '.' in i:
      print(i,end='\n')
    else:
      print(i,end=' ')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
speech(sp)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# testing the chatbot
def main():
  print(' try typing "what can you do?"')
  while True:  
      global res
      print ("Enter a sentence")
      sentence = input('type: ')
      prediction= model.predict(np.array([encode_sentence(sentence)]))
#      print (classes[argmax(prediction)])
      cls=classes[argmax(prediction)]
 #   if 'search' or 'google' in (sentence.lower()).split():
  #    cls='google'
#    if 'game' in (sentence.lower().split or sentence.lower()):
#     cls='game'
      if cls=='bye':
        res=random.choice(b_bye)
        print(res)
        break
      elif cls == 'greets':
        res=random.choice(b_greets)
      elif cls=='hows':
        res=random.choice(b_hows)
      elif cls=='whats':
        res=random.choice(b_whats)
#        here ###################
      elif cls=='google':
        search()
        print('results from the web : ')
        res=''
        for i in stat:
          print(i.getText())
          print("------")
      elif cls=='summary' :
        summary()
        res=' ' 
      elif cls=='game':
        print('ok..lets play tic tac toe !')
        res=''
        game()
      elif cls=='weather':
        weather()
        t='the temperature in kochi is : '
        res=t + temp
      elif cls=='do':
     # print('i can play game with you ,tell the population of a country','and eve search google for you queries!','tell the weather',sep='\n')
        print("I can tell you if your password has been pawned/breached","tell you the current weather","play small games","tell the population of a place","and even search for any of your queries in google!",'just ask',sep='\n')
        res=''
      elif cls=='population':
        population()
        res='the tottal population of '+city+' is '+popu
      elif cls=='pawned':
        pawned()
        res=''
      res=str(res)
      print(res)
main()
sp='it was nice chatting with you.  ' + random.choice(b_bye)
speech(sp)
Audio(sound_file,autoplay=True)
# Out:
#  try typing "what can you do?"
# Enter a sentence
# type: summary
# what do you want to summarize?
# 1) text
#  2) a link to source text
# 2
# enter the link to the text  : https://en.wikipedia.org/wiki/Main_Page
#
#
#
# length of input  :  967
# length of output :  689
#  press enter to show the summary
# Described by George Shaw in 1794, it is one of eastern Australia's most commonly encountered snakes.
# Averaging around 1.25
# metres (4 ft) in length when fully grown, it has glossy black upperparts, bright red or orange flanks and a pink or dull red belly.
# Although its venom is capable of causing significant illness, containing neurotoxins, myotoxins, coagulants and haemolysins, it is less venomous than that of other Australian elapid snakes, and no humans have been confirmed to have died from its bite.
# The snake forages in bodies of shallow water, commonly with tangles of water plants and logs, where it hunts frogs, its main prey item, as well as fish, reptiles and small mammals.
#
# Enter a sentence
# type: weather
# where are you now?  :   kochi
# the temperature in kochi is : 26°C
# Enter a sentence
# type: population
# Type the name of the country/state/district :  kerala
# the tottal population of kerala is 34.63 million (2018)
# Enter a sentence
# type: bii
# ciao
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-34f58bc99ad4> in <module>()
#      57 sp='it was nice chatting with you.  ' + random.choice(b_bye)
#      58 speech(sp)
# ---> 59 Audio(sound_file,autoplay=True)
#
# NameError: name 'sound_file' is not defined
